# %% [markdown]
# <a href="https://colab.research.google.com/github/nayelhashmi2000/DeepLearning/blob/master/Intro_to_TensorFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units = 1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 13.7080
# Epoch 2/500
# 1/1 [==============================] - 0s 2ms/step - loss: 11.0178
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 8.8965
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.2228
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.9015
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.8575
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.0316
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 3.3776
# Epoch 9/500
# 1/1 [==============================] - 0s 1ms/step - loss: 2.8588
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.4465
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.1181
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8557
# ...

# %%
model.predict([10.0]) #almost close to the real answer that is 19, this is due to a small dataset
# Out:
# array([[18.981913]], dtype=float32)
